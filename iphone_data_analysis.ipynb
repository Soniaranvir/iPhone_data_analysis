# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Downloads/apple_products.csv")

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.count()
# Out:
# Product Name           62
# Product URL            62
# Brand                  62
# Sale Price             62
# Mrp                    62
# Discount Percentage    62
# Number Of Ratings      62
# Number Of Reviews      62
# Upc                    62
# Star Rating            62
# Ram                    62
# dtype: int64

# %%
df['Mrp'].max()
# Out:
# np.int64(149900)

# %%
df['Mrp'].min()
# Out:
# np.int64(39900)

# %%
df[df['Mrp']==149900]
# Out:
#                                   Product Name  \
# 24        APPLE iPhone 12 Pro (Silver, 512 GB)
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 24  149900                    6                542                 42
# 41  149900                    6                545                 42
#
#                  Upc  Star Rating   Ram
# 24  MOBFWBYZ5UY6ZBVA          4.5  4 GB
# 41  MOBFWBYZTHSXKMGW          4.5  4 GB

# %%
df[df['Mrp']==39900]
# Out:
#                       Product Name  \
# 52  APPLE iPhone SE (White, 64 GB)
# 57  APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 52  39900                   24              95807               8154
# 57  39900                   24              95909               8161
#
#                  Upc  Star Rating   Ram
# 52  MOBFWQ6BGWDVGF3E          4.5  2 GB
# 57  MOBFWQ6BR3MK7AUG          4.5  4 GB

# %%
df[df['Mrp']<=50000]
# Out:
#                                          Product Name  \
# 0                   APPLE iPhone 8 Plus (Gold, 64 GB)
# 5                 APPLE iPhone 8 Plus (Silver, 64 GB)
# 6             APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...
# 52                     APPLE iPhone SE (White, 64 GB)
# 53                    APPLE iPhone SE (Black, 128 GB)
# 54                    APPLE iPhone SE (White, 128 GB)
# 55                      APPLE iPhone SE (Red, 128 GB)
# 57                     APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 5   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       49900
# 6   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       49900
# 10  https://www.flipkart.com/apple-iphone-xr-black...  Apple       39999
# ...

# %%
df[df['Mrp']>=100000]
# Out:
#                                         Product Name  \
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 18       APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 19          APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 21      APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# 22          APPLE iPhone 11 Pro (Space Grey, 256 GB)
# 24              APPLE iPhone 12 Pro (Silver, 512 GB)
# 25    APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 27            APPLE iPhone 12 Pro (Graphite, 256 GB)
# 30            APPLE iPhone 12 Pro (Graphite, 128 GB)
# 31        APPLE iPhone 12 Pro Max (Graphite, 256 GB)
# 32        APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 37          APPLE iPhone 12 Pro Max (Silver, 128 GB)
# 39            APPLE iPhone 12 Pro Max (Gold, 128 GB)
# ...

# %%
df['Product Name']
# Out:
# 0            APPLE iPhone 8 Plus (Gold, 64 GB)
# 1     APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2         APPLE iPhone 8 Plus (Silver, 256 GB)
# 3              APPLE iPhone 8 (Silver, 256 GB)
# 4                APPLE iPhone 8 (Gold, 256 GB)
#                         ...
# 57              APPLE iPhone SE (Black, 64 GB)
# 58             APPLE iPhone 11 (Purple, 64 GB)
# 59              APPLE iPhone 11 (White, 64 GB)
# 60              APPLE iPhone 11 (Black, 64 GB)
# 61                APPLE iPhone 11 (Red, 64 GB)
# Name: Product Name, Length: 62, dtype: object

# %%
type(df['Product Name'])
# Out:
# pandas.core.series.Series

# %%
list(df['Product Name'])[23][6:15].upper().strip()
# Out:
# 'IPHONE SE'

# %%
df['Model Name'] = df['Product Name'].str[6:15]

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.sort_values(by=['Star Rating'], ascending = False)
# Out:
#                                          Product Name  \
# 20    APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17        APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16   APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15              APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14             APPLE iPhone 11 Pro Max (Gold, 256 GB)
# ..                                                ...
# 45                APPLE iPhone 12 Mini (Black, 64 GB)
# 28                APPLE iPhone 12 Mini (White, 64 GB)
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...
# 41         APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 27             APPLE iPhone 12 Pro (Graphite, 256 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# ...

# %%
unique_model_name = df['Model Name'].unique()

# %%
print(unique_model_name)
# Out:
# ['iPhone 8 ' 'iPhone XS' 'iPhone XR' 'iPhone 11' 'iPhone SE' 'iPhone 12']

# %%
average_sale_price = df['Sale Price'].mean()

# %%
print(f"The average sale price of the iPhones listed is: {average_sale_price}")
# Out:
# The average sale price of the iPhones listed is: 80073.8870967742

# %%
total_reviews = df['Number Of Reviews'].sum()
print(f"The total number of reviews for all products is: {total_reviews}")
# Out:
# The total number of reviews for all products is: 115424

# %%
# Extracting the color from the 'Product Name' (assuming color is mentioned in the name)
# This assumes that the color is mentioned before the storage capacity (e.g., 'Midnight Green', 'Gold')
color_counts = df['Product Name'].str.extract(r'(\w+ \w+)')[0].value_counts()

print("Number of products for each color variant:")
print(color_counts)
# Out:
# Number of products for each color variant:
# 0
# APPLE iPhone    56
# Apple iPhone     6
# Name: count, dtype: int64

# %%
#Distribution of Star Ratings
#This will help understand the spread of customer ratings for iPhones.
plt.figure(figsize=(8, 6))
sns.histplot(df['Star Rating'], bins=10, kde=True, color='blue')
plt.title('Distribution of Star Ratings')
plt.xlabel('Star Rating')
plt.ylabel('Frequency')
plt.show()

# %%
#Scatter Plot: Discount Percentage vs. Number of Ratings
#This visualization helps to understand if higher discounts attract more customer reviews.

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Discount Percentage', y='Number Of Ratings', data=df, hue='Star Rating', palette='viridis')
plt.title('Discount Percentage vs. Number of Ratings')
plt.xlabel('Discount Percentage')
plt.ylabel('Number of Ratings')
plt.legend(title='Star Rating', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#Price Trends Across Models
#A bar chart to show the average sale price of different iPhone models.

avg_price_by_model = df.groupby('Model Name')['Sale Price'].mean().sort_values()

plt.figure(figsize=(10, 8))
avg_price_by_model.plot(kind='barh', color='orange')
plt.title('Average Sale Price by iPhone Model')
plt.xlabel('Average Sale Price')
plt.ylabel('iPhone Model')
plt.show()

# %%
#Relationship Between Sale Price and Star Rating
#A scatter plot to analyze if higher-priced models have better ratings.

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Sale Price', y='Star Rating', data=df, hue='Star Rating', palette='coolwarm')
plt.title('Sale Price vs. Star Rating')
plt.xlabel('Sale Price')
plt.ylabel('Star Rating')
plt.legend(title='Star Rating', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#Heatmap: Correlations Between Variables
#This will show correlations between numerical variables like prices, discounts, and ratings.

# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='Blues', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#Distribution of Discount Percentages
#This histogram will show how discounts vary across iPhone models.

plt.figure(figsize=(8, 6))
sns.histplot(df['Discount Percentage'], bins=10, kde=True, color='green')
plt.title('Distribution of Discount Percentages')
plt.xlabel('Discount Percentage')
plt.ylabel('Frequency')
plt.show()
